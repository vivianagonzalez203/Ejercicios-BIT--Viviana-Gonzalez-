# %%
Pandas

# %%
# Si es necesario instalar
# !pip install pandas

import pandas as pd
print(f"Versión de Pandas: {pd.__version__}")
# Out:
# Versión de Pandas: 2.2.3

# %%
# Crear una Serie
edades = pd.Series([25, 30, 35, 40], name="Edades")
print("Serie de Edades:")
edades
# Out:
# Serie de Edades:
# 0    25
# 1    30
# 2    35
# 3    40
# Name: Edades, dtype: int64

# %%
# Crear un DataFrame desde un diccionario
data = {
    'Nombre': ['Ana', 'Juan', 'Sofía', 'Carlos'],
    'Edad': [25, 30, 35, 40],
    'Ciudad': ['Madrid', 'Barcelona', 'Valencia', 'Sevilla']
}

df = pd.DataFrame(data)
print("\nDataFrame:")
df
# Out:
# DataFrame:
#    Nombre  Edad     Ciudad
# 0     Ana    25     Madrid
# 1    Juan    30  Barcelona
# 2   Sofía    35   Valencia
# 3  Carlos    40    Sevilla

# %%
import pandas as pd
titanic = pd.read_csv("C:/Users/vivia/Downloads/Titanic-Dataset.csv")
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.info()
titanic.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# ...

# %%
# Atributos básicos
print("Índice del DataFrame:", titanic.index)
print()
print("Columnas disponibles:", titanic.columns)
print()
print("Tipos de datos:\n", titanic.dtypes) #data types - tipos de datos
print()
# Out:
# Índice del DataFrame: RangeIndex(start=0, stop=891, step=1)
#
# Columnas disponibles: Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
#
# Tipos de datos:
#  PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# Si no tienes un Excel, créalo así:
ventas = pd.DataFrame({
    'OrderID': range(1, 11),
    'Date': pd.date_range('2023-01-01', periods=10),
    'Product': ['A', 'B'] * 5,
    'Country': ['Estados Unidos', 'Peru', 'Chile', 'Argentina', 'Mexico'] * 2,
    'Amount': [100, 150, 200, 120, 80, 95, 60, 130, 180, 110]
})
ventas.to_excel('ventas.xlsx', index=False)

# %%
titanic.sort_values(by='Age',ascending=False) # Ordenar por una columna
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 630          631         1       1      Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                       Svensson, Mr. Johan
# 493          494         0       1                   Artagaveytia, Mr. Ramon
# 96            97         0       1                 Goldschmidt, Mr. George B
# 116          117         0       3                      Connors, Mr. Patrick
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
titanic.head() # 5 primeras filas
titanic.tail() # 5 ultimas filas
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# Ver columnas especificas
print("Ver nombre, edad y sexo:")
titanic[['Name', 'Age', 'Sex']]
# Out:
# Ver nombre, edad y sexo:
#                                                   Name   Age     Sex
# 0                              Braund, Mr. Owen Harris  22.0    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female
# 2                               Heikkinen, Miss. Laina  26.0  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female
# 4                             Allen, Mr. William Henry  35.0    male
# ..                                                 ...   ...     ...
# 886                              Montvila, Rev. Juozas  27.0    male
# 887                       Graham, Miss. Margaret Edith  19.0  female
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN  female
# 889                              Behr, Mr. Karl Howell  26.0    male
# 890                                Dooley, Mr. Patrick  32.0    male
#
# [891 rows x 3 columns]

# %%
# Filtro básico
print("Pasajeros de primera clase:")
titanic[titanic['Ticket'].str.contains("PC")]
# Out:
# Pasajeros de primera clase:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 30            31         0       1
# 31            32         1       1
# 34            35         0       1
# 52            53         1       1
# 64            65         0       1
# 96            97         0       1
# 97            98         1       1
# 118          119         0       1
# 139          140         0       1
# 155          156         0       1
# 168          169         0       1
# 177          178         0       1
# 194          195         1       1
# 195          196         1       1
# 256          257         1       1
# 258          259         1       1
# 268          269         1       1
# 269          270         1       1
# 273          274         0       1
# 295          296         0       1
# 299          300         1       1
# 307          308         1       1
# 309          310         1       1
# 311          312         1       1
# ...

# %%
# Renombrar columna
titanic = titanic.rename(columns=
 {'Survived':"Sobrevivió?",
  "Age":"Edad",
 })
titanic
# Out:
#      PassengerId  Sobrevivió?  Pclass  \
# 0              1            0       3
# 1              2            1       1
# 2              3            1       3
# 3              4            1       1
# 4              5            0       3
# ..           ...          ...     ...
# 886          887            0       2
# 887          888            1       1
# 888          889            0       3
# 889          890            1       1
# 890          891            0       3
#
#                                                   Name     Sex  Edad  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
# Renombrar columna
titanic = titanic.rename(columns=
 {'Sobrevivió?':"Survived?",
  "Edad":"Age",
 })
titanic
# Out:
#      PassengerId  Survived?  Pclass  \
# 0              1          0       3
# 1              2          1       1
# 2              3          1       3
# 3              4          1       1
# 4              5          0       3
# ..           ...        ...     ...
# 886          887          0       2
# 887          888          1       1
# 888          889          0       3
# 889          890          1       1
# 890          891          0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
# Filtro multiple
## & : Conjuncion - AND
## | : Disyuncion - OR
print("Pasajeras de primera clase menores de 40 años:")
mujeres_primeraclase_menoresde40 = titanic[(titanic['Pclass'] == 1) & (titanic['Sex'] == 'female') & (titanic['Age'] < 40) & (titanic['Name'].str.contains("Miss"))]
mujeres_primeraclase_menoresde40.shape
# Out:
# Pasajeras de primera clase menores de 40 años:
# (37, 12)
