# %%
# !pip install dash
# !pip install dash-bootstrap-components
# Out:
# ...
#    ---------------------------------------- 0.0/7.9 MB ? eta -:--:--
#    --------- ------------------------------ 1.8/7.9 MB 9.5 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.7/7.9 MB 11.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.1/7.9 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------- 7.9/7.9 MB 10.1 MB/s eta 0:00:00
# ...
#
#    -------------------- ------------------- 1/2 [dash]
#    -------------------- ------------------- 1/2 [dash]
#    -------------------- ------------------- 1/2 [dash]
#    -------------------- ------------------- 1/2 [dash]
#    -------------------- ------------------- 1/2 [dash]
#    -------------------- ------------------- 1/2 [dash]
#    -------------------- ------------------- 1/2 [dash]
#    -------------------- ------------------- 1/2 [dash]
#    -------------------- ------------------- 1/2 [dash]
#    -------------------- ------------------- 1/2 [dash]
# ...

# %%
conda install -c conda-forge dash-bootstrap-components

# %%
import pandas as pd
from dash import Dash, dcc, html, Input, Output
import plotly.express as px
import dash_bootstrap_components as dbc

# %% [markdown]
# ## Utilizar http://dash-bootstrap-components.com/. Es una libreria con componentes predefinidos para construir el reporte de una manera mucho más sencilla

# %% [markdown]
# Reporte interactivo: https://reportedashonlinefoods-1.onrender.com/

# %% [markdown]
# https://reporte-dash-11-5-2025.onrender.com/
